# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline 

from matplotlib.pylab import rcParams
rcParams['figure.figsize']=20,10

from sklearn.preprocessing import MinMaxScaler
pd.options.mode.chained_assignment = None  # default='warn'

from keras.models import Sequential
from keras.layers import LSTM,Dense
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\goldy\Desktop\Stock_Prediction.ipynb Cell 1 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/c%3A/Users/goldy/Desktop/Stock_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a> from matplotlib.pylab import rcParams
#       <a href='vscode-notebook-cell:/c%3A/Users/goldy/Desktop/Stock_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a> rcParams['figure.figsize']=20,10
# ---> <a href='vscode-notebook-cell:/c%3A/Users/goldy/Desktop/Stock_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a> from sklearn.preprocessing import MinMaxScaler
#      <a href='vscode-notebook-cell:/c%3A/Users/goldy/Desktop/Stock_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a> pd.options.mode.chained_assignment = None  # default='warn'
#      <a href='vscode-notebook-cell:/c%3A/Users/goldy/Desktop/Stock_Prediction.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a> from keras.models import Sequential
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df=pd.read_csv("NSE-Tata-Global-Beverages-Limited.csv")

# %%
 
df["Date"]=pd.to_datetime(df.Date,format="%Y-%m-%d")
df.index=df['Date']

plt.figure(figsize=(16,8))
plt.plot(df["Close"],label='Close Price history')

# %%
#Sort the dataset on date time

data=df.sort_index(ascending=True,axis=0)
new_dataset=pd.DataFrame(index=range(0,len(df)),columns=['Date','Close'])

for i in range(0,len(data)):
    new_dataset["Date"][i]=data['Date'][i]
    new_dataset["Close"][i]=data["Close"][i]  

new_dataset.index=new_dataset.Date
new_dataset.drop("Date",axis=1,inplace=True)

final_dataset=new_dataset.values

#Divide the dataset in ratio of 80:20 to train and test data

train_data=final_dataset[0:987,:]
valid_data=final_dataset[987:,:]

#Scaling and Normalization

scaler=MinMaxScaler(feature_range=(0,1))
scaled_data=scaler.fit_transform(final_dataset)

x_train_data,y_train_data=[],[]

for i in range(60,len(train_data)):
    x_train_data.append(scaled_data[i-60:i,0])
    y_train_data.append(scaled_data[i,0])

#Convert them to numpy arrays    
    
x_train_data,y_train_data=np.array(x_train_data),np.array(y_train_data)
x_train_data=np.reshape(x_train_data,(x_train_data.shape[0],x_train_data.shape[1],1))

#Create Model

lstm_model=Sequential()
lstm_model.add(LSTM(units=50,return_sequences=True,input_shape=(x_train_data.shape[1],1)))
lstm_model.add(LSTM(units=50))
lstm_model.add(Dense(1))

lstm_model.compile(loss='mean_squared_error',optimizer='adam')
lstm_model.fit(x_train_data,y_train_data,epochs=1,batch_size=1)

inputs_data=new_dataset[len(new_dataset)-len(valid_data)-60:].values
inputs_data=inputs_data.reshape(-1,1)
inputs_data=scaler.transform(inputs_data)

X_test=[]
for i in range(60,inputs_data.shape[0]):
    X_test.append(inputs_data[i-60:i,0])
X_test=np.array(X_test)

X_test=np.reshape(X_test,(X_test.shape[0],X_test.shape[1],1))
closing_price=lstm_model.predict(X_test)
closing_price=scaler.inverse_transform(closing_price)

lstm_model.save("saved_lstm_model.h5")

train_data=new_dataset[:987]
valid_data=new_dataset[987:]
valid_data['Predictions']=closing_price
plt.plot(train_data["Close"])
plt.plot(valid_data[['Close',"Predictions"]])
plt.title('Stock Price Prediction', fontsize = 30)
plt.xlabel('Date', fontsize=25)
plt.ylabel('Closing Price', fontsize=25)
plt.legend(['Train','Test','Predicted'], loc='upper left', prop={'size': 20})
# Out:
# 927/927 [==============================] - 21s 19ms/step - loss: 0.0011
# 8/8 [==============================] - 1s 14ms/step

# %%
plt.plot(valid_data['Close'])
plt.plot(valid_data['Predictions'])
plt.title('Stock Price Prediction', fontsize = 30)
plt.xlabel('Date', fontsize=25)
plt.ylabel('Closing Price', fontsize=25)
plt.legend(['Test','Predicted'], loc='upper right', prop={'size': 20})
